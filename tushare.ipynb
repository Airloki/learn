# %%
import tushare as ts

# %%
df = ts.get_hist_data(stock,start = '2016-01-01').iloc[:,0:7]

# %%
df
# Out:
#              open   high  close   low     volume  price_change  p_change
# date
# 2018-02-23   5.00   5.14   4.93  4.90  823272.31          0.06      1.23
# 2018-02-22   4.70   5.01   4.87  4.64  591155.12          0.23      4.96
# 2018-02-14   4.60   4.65   4.63  4.58  198471.81          0.03      0.65
# 2018-02-13   4.55   4.74   4.60  4.53  294883.06          0.10      2.22
# 2018-02-12   4.47   4.53   4.50  4.45  172166.81          0.06      1.35
# 2018-02-09   4.58   4.64   4.44  4.29  372478.62         -0.25     -5.33
# 2018-02-08   4.64   4.72   4.69  4.60  212955.30          0.05      1.08
# 2018-02-07   4.72   4.75   4.63  4.54  323449.34          0.01      0.22
# 2018-02-06   4.95   4.95   4.63  4.60  506127.81         -0.39     -7.77
# 2018-02-05   5.06   5.06   5.02  4.97  281165.91         -0.03     -0.59
# 2018-02-02   5.00   5.06   5.05  4.88  289540.59          0.05      1.00
# 2018-02-01   5.20   5.22   5.00  4.99  486768.84         -0.17     -3.29
# ...

# %%
a = 'sh02'

# %%
df.to_csv('d:/data/stocks/'+a+'.csv')

# %%
stock = ts.get_hs300s()['code'][1]
# Out:
# http://www.csindex.com.cn/uploads/file/autofile/closeweight/000300closeweight.xls

# %%
hs300 =  ts.get_hs300s()['code']
# Out:
# http://www.csindex.com.cn/uploads/file/autofile/closeweight/000300closeweight.xls

# %%
for stock in hs300:
    df = ts.get_hist_data(stock,start = '2016-01-01').iloc[:,0:7]
    df.to_csv('d:/data/stocks/'+stock+'.csv')
